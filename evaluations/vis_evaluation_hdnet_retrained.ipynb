# %%
from __future__ import absolute_import, division, print_function

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath('..')

if project_root not in sys.path:
    sys.path.append(project_root)

print(f"Added to path: {project_root}")
# Out:
# Added to path: /home/gabriel/Hyper-Skin-2023

# %% [markdown]
# Evaluation:
# 1. Evaluate on the pretrained models: download the pretrained model [here](https://drive.google.com/drive/folders/1G1GOA0FthtmOERJIJ0pALOSgXc6XOfoY) (credit: caiyuanhao)
# 2. Evaluate on the models retrained with Hyper-Skin data:
# 3. Do step 1-2 for (RGB, VIS) data, and only step 2 for (MSI, NIR) data (reason, all pretrained model is based on input with in_channels = 3)
# 4. For all, compute the SSIM (for spatial evaluation) and SAM (for spectral evaluation)

# %%
import os 
import cv2 
import pickle
import spectral
import spectral.io.envi as envi
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

import torch
from torchvision import transforms
from torchmetrics import SpectralAngleMapper, StructuralSimilarityIndexMeasure

from hsiData import HyperSkinData
from helpers import metrics 
from hsiData.models.reconstruction import MST_Plus_Plus, HSCNN_Plus, hrnet, HDNet

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# /home/gabriel/.venv/lib/python3.12/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `StructuralSimilarityIndexMeasure` from `torchmetrics` was deprecated and will be removed in 2.0. Import `StructuralSimilarityIndexMeasure` from `torchmetrics.image` instead.
#   _future_warning(

# %%
data_dir = '/mnt/data/HyperSkin2023'
rgbvis_dir = f'{data_dir}/Hyper-Skin(RGB, VIS)'
# mask_dir = f'{data_dir}/mask'
pretrained_dir  = '/home/gabriel/Hyper-Skin-2023/saved-models/exp-HDNET-CIE'

# directories to the test data 
rgb_dir = f'{rgbvis_dir}/test/RGB'
vis_dir = f'{rgbvis_dir}/test/VIS'
# mask_dir = f'{mask_dir}/test'

# directory to save the results
results_dir = '/home/gabriel/Hyper-Skin-2023/evaluationResults'
if not os.path.exists(results_dir):
    os.mkdir(results_dir)

# %%
test_transform = transforms.Compose([
        transforms.ToTensor()
    ])
test_dataset = HyperSkinData.Load(
            hsi_dir = vis_dir,
            rgb_dir = rgb_dir, 
            transform = test_transform
    )
test_loader = torch.utils.data.DataLoader(
                                    dataset = test_dataset, 
                                    batch_size = 1, 
                                    shuffle = False,
                                    pin_memory = False)

# %% [markdown]
# 1. Evaluation: HRNET (Pretrained on NTIRE)

# %%
# load the pretrained model from NTIRE 
model = HDNet.HDNet()
checkpoint = torch.load(f'{pretrained_dir}/model.pt')
model.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %%
model.to(device)
model.eval() 
results = {
    "file": [],
    "pred": [],
    "ssim_score": [],
    "ssim_map": [],
    "sam_score": [],
    "sam_map": []
}
metrics.ssim_fn.to(device)
for k, data in enumerate(test_loader):
    x, y = data 
    x, y = x.float().to(device), y.float().to(device)

    with torch.no_grad():
        pred = model(x)

    ssim_score, ssim_map = metrics.ssim_fn(pred, y)
    sam_score, sam_map = metrics.sam_fn(pred, y)

    results["file"].append(test_dataset.rgb_files[0].split('\\')[-1].split('.')[0])
    results["pred"].append(pred.cpu().detach().numpy())
    results["ssim_score"].append(ssim_score.cpu().detach().numpy())
    results["ssim_map"].append(ssim_map.cpu().detach().numpy())
    results["sam_score"].append(sam_score.cpu().detach().numpy())
    results["sam_map"].append(sam_map.cpu().detach().numpy())
    
    print(f"Test [{k}/{len(test_loader)}]: {results['file'][-1]}, SSIM: {results['ssim_score'][-1]}, SAM: {results['sam_score'][-1]}")    

# save the results in pickle format
with open(f'{results_dir}/hdnet.pkl', 'wb') as f:
    pickle.dump(results, f)
# Out:
# Test [0/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9076594710350037, SAM: 0.22825400531291962
# Test [1/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9199985265731812, SAM: 0.21852245926856995
# Test [2/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9241390824317932, SAM: 0.20511478185653687
# Test [3/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9203546643257141, SAM: 0.21324600279331207
# Test [4/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.90579754114151, SAM: 0.21381035447120667
# Test [5/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9325272440910339, SAM: 0.2022811770439148
# Test [6/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9349910616874695, SAM: 0.13081470131874084
# Test [7/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.932887077331543, SAM: 0.13883399963378906
# Test [8/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9385251402854919, SAM: 0.12629030644893646
# Test [9/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9370279312133789, SAM: 0.13385415077209473
# Test [10/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9385878443717957, SAM: 0.14193160831928253
# Test [11/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9423691034317017, SAM: 0.12805350124835968
# Test [12/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9499218463897705, SAM: 0.12539151310920715
# Test [13/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9382160305976868, SAM: 0.13540202379226685
# Test [14/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9393208622932434, SAM: 0.12674880027770996
# Test [15/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9472163915634155, SAM: 0.12715381383895874
# Test [16/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9357656240463257, SAM: 0.13423320651054382
# Test [17/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9436869025230408, SAM: 0.1269311010837555
# Test [18/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9375950694084167, SAM: 0.13283771276474
# Test [19/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9407784938812256, SAM: 0.1430075466632843
# Test [20/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9366407990455627, SAM: 0.1291513442993164
# Test [21/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9461176991462708, SAM: 0.1323811113834381
# Test [22/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9403345584869385, SAM: 0.1391994208097458
# Test [23/24]: /mnt/data/HyperSkin2023/Hyper-Skin(RGB, VIS)/test/RGB/p002_neutral_front, SSIM: 0.9439665079116821, SAM: 0.12854982912540436

# %%
# compute the mean and std of the SSIM and SAM scores
ssim_scores = np.array(results["ssim_score"])
ssim_mean = np.mean(ssim_scores)
ssim_std = np.std(ssim_scores)

sam_scores = np.array(results["sam_score"])
sam_mean = np.mean(sam_scores)
sam_std = np.std(sam_scores)
print(f"SSIM: {ssim_mean:.4f} +/- {ssim_std:.4f}")
print(f"SAM: {sam_mean:.4f} +/- {sam_std:.4f}")
# Out:
# SSIM: 0.9348 +/- 0.0112
# SAM: 0.1526 +/- 0.0358

# %%
# visualize the ssim map for 31 bands to understand which band has better ssim score
band_31 = np.arange(400, 710, 10)
ssim_map = np.array(results["ssim_map"]).squeeze()
fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(26, 10))
for i, ax in enumerate(axes.flat[:-1]):
    im = ax.imshow(ssim_map[6, i, :, :], vmin=0, vmax=1, cmap='gray')
    ax.axis('off')
    ax.set_title(f"{band_31[i]}nm, SSIM: {ssim_map[6, i, :, :].mean():.3f}")
fig.colorbar(im, ax=axes.ravel().tolist(), pad = 0.01)
plt.show()

# %%
# visualize the sam map for 31 bands to understand which band has better ssim score
sam_map = np.array(results["sam_map"]).squeeze()
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 15))
for i, ax in enumerate(axes.flat[:-1]):
    im = ax.imshow(sam_map[i, :, :], vmin=0, vmax=1, cmap='gray')
    ax.axis('off')
    ax.set_title(f"SAM: {sam_map[i, :, :].mean():.3f}")
fig.colorbar(im, ax=axes.ravel().tolist(), pad = 0.01)
plt.show()
sam_map.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 5
#       3 fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 15))
#       4 for i, ax in enumerate(axes.flat[:-1]):
# ----> 5     im = ax.imshow(sam_map[i, :, :], vmin=0, vmax=1, cmap='gray')
#       6     ax.axis('off')
#       7     ax.set_title(f"SAM: {sam_map[i, :, :].mean():.3f}")
#
# IndexError: index 24 is out of bounds for axis 0 with size 24

# %%
h, w, hwsize = 250, 500, 100
x, y = test_dataset[6]
y = y.numpy()
p = np.array(results["pred"]).squeeze()[6]

yy = y[:, h:h+hwsize, w:w+hwsize].reshape(-1, 10000)
yy_median = np.median(yy, axis=1)
yy_max = yy.max(1)
yy_min = yy.min(1)
pp = p[:, h:h+hwsize, w:w+hwsize].reshape(-1, 10000)
pp_median = np.median(pp, axis=1)
pp_max = pp.max(1)
pp_min = pp.min(1)

# %%
plt.imshow(x.permute(1, 2, 0).numpy())

# Add the patch to the Axes
plt.gca().add_patch(Rectangle((w,h),hwsize,hwsize,linewidth=1.2,edgecolor='r',facecolor='none'))

# %%
plt.plot(band_31, yy_median, label='Groud truth')
plt.fill_between(band_31, yy_min, yy_max, alpha=0.2)
plt.plot(band_31, pp_median, label='Prediction')
plt.fill_between(band_31, pp_min, pp_max, alpha=0.2)
plt.title('Spectral profile at (300, 500)')
plt.legend()
plt.ylabel('Reflectance')
plt.xlabel('Band')
plt.show()

# %% [markdown]
# 1. only evaluate on the human subject - discard the background

# %%
model.to(device)
model.eval() 
results_m = {
    "file": [],
    "pred": [],
    "ssim_score": [],
    "ssim_map": [],
    "sam_score": [],
    "sam_map": []
}
masks = sorted(os.listdir(mask_dir))
for k, data in enumerate(test_loader):
    x, y = data 
    x, y = x.float().to(device), y.float().to(device)

    mask = plt.imread(f"{mask_dir}/{masks[k]}")/255
    mask = torch.from_numpy(mask[:,:,0]).float().to(device)

    with torch.no_grad():
        pred = model(x)
        pred = pred * mask[None, None, ...]
        y = y * mask[None, None, ...]

    ssim_score, ssim_map = metrics.ssim_fn.to(device)(pred, y)
    sam_score, sam_map = metrics.sam_fn(pred, y)

    results_m["file"].append(test_dataset.rgb_files[0].split('\\')[-1].split('.')[0])
    results_m["pred"].append(pred.cpu().detach().numpy())
    results_m["ssim_score"].append(ssim_score.cpu().detach().numpy())
    results_m["ssim_map"].append(ssim_map.cpu().detach().numpy())
    results_m["sam_score"].append(sam_score.cpu().detach().numpy())
    results_m["sam_map"].append(sam_map.cpu().detach().numpy())
    
    print(f"Test [{k}/{len(test_loader)}]: {results_m['file'][-1]}, SSIM: {results_m['ssim_score'][-1]}, SAM: {results_m['sam_score'][-1]}")    

# save the results in pickle format
with open(f'{results_dir}/masked_hrnet.pkl', 'wb') as f:
    pickle.dump(results_m, f)
# Out:
# Test [0/30]: p005_neutral_front, SSIM: 0.9771792888641357, SAM: 0.12969404458999634
# Test [1/30]: p005_neutral_front, SSIM: 0.9331232905387878, SAM: 0.17269599437713623
# Test [2/30]: p005_neutral_front, SSIM: 0.9636531472206116, SAM: 0.14043965935707092
# Test [3/30]: p005_neutral_front, SSIM: 0.976667046546936, SAM: 0.13037678599357605
# Test [4/30]: p005_neutral_front, SSIM: 0.9601147770881653, SAM: 0.14363957941532135
# Test [5/30]: p005_neutral_front, SSIM: 0.9750713109970093, SAM: 0.13181418180465698
# Test [6/30]: p005_neutral_front, SSIM: 0.966361939907074, SAM: 0.12818248569965363
# Test [7/30]: p005_neutral_front, SSIM: 0.9717045426368713, SAM: 0.12292078137397766
# Test [8/30]: p005_neutral_front, SSIM: 0.9614012837409973, SAM: 0.12968088686466217
# Test [9/30]: p005_neutral_front, SSIM: 0.9676527976989746, SAM: 0.12541386485099792
# Test [10/30]: p005_neutral_front, SSIM: 0.9689102172851562, SAM: 0.12140879780054092
# Test [11/30]: p005_neutral_front, SSIM: 0.9617401957511902, SAM: 0.12978242337703705
# Test [12/30]: p005_neutral_front, SSIM: 0.9571160078048706, SAM: 0.12920919060707092
# Test [13/30]: p005_neutral_front, SSIM: 0.9571505784988403, SAM: 0.12451430410146713
# Test [14/30]: p005_neutral_front, SSIM: 0.9516614675521851, SAM: 0.1261427104473114
# Test [15/30]: p005_neutral_front, SSIM: 0.954393208026886, SAM: 0.12773852050304413
# Test [16/30]: p005_neutral_front, SSIM: 0.9683099985122681, SAM: 0.12483375519514084
# Test [17/30]: p005_neutral_front, SSIM: 0.9456436634063721, SAM: 0.12773455679416656
# Test [18/30]: p005_neutral_front, SSIM: 0.9696511626243591, SAM: 0.1188785508275032
# Test [19/30]: p005_neutral_front, SSIM: 0.9698315262794495, SAM: 0.11837685853242874
# Test [20/30]: p005_neutral_front, SSIM: 0.9653090834617615, SAM: 0.11679407209157944
# Test [21/30]: p005_neutral_front, SSIM: 0.9735885858535767, SAM: 0.11719129979610443
# Test [22/30]: p005_neutral_front, SSIM: 0.9663963913917542, SAM: 0.12090795487165451
# Test [23/30]: p005_neutral_front, SSIM: 0.9653582572937012, SAM: 0.1176355630159378
# Test [24/30]: p005_neutral_front, SSIM: 0.9596136808395386, SAM: 0.14497001469135284
# Test [25/30]: p005_neutral_front, SSIM: 0.9554482102394104, SAM: 0.1564728170633316
# Test [26/30]: p005_neutral_front, SSIM: 0.948228120803833, SAM: 0.15138761699199677
# Test [27/30]: p005_neutral_front, SSIM: 0.9094866514205933, SAM: 0.1751476228237152
# Test [28/30]: p005_neutral_front, SSIM: 0.9675551652908325, SAM: 0.15161104500293732
# Test [29/30]: p005_neutral_front, SSIM: 0.947812020778656, SAM: 0.14608906209468842

# %%
# compute the mean and std of the SSIM and SAM scores
ssim_scores = np.array(results_m["ssim_score"])
ssim_mean = np.mean(ssim_scores)
ssim_std = np.std(ssim_scores)

sam_scores = np.array(results_m["sam_score"])
sam_mean = np.mean(sam_scores)
sam_std = np.std(sam_scores)
print(f"SSIM: {ssim_mean:.4f} +/- {ssim_std:.4f}")
print(f"SAM: {sam_mean:.4f} +/- {sam_std:.4f}")
# Out:
# SSIM: 0.9605 +/- 0.0137
# SAM: 0.1334 +/- 0.0153

# %%
# visualize the ssim map for 31 bands to understand which band has better ssim score
band_31 = np.arange(400, 710, 10)
ssim_map = np.array(results_m["ssim_map"]).squeeze()
fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(26, 10))
for i, ax in enumerate(axes.flat[:-1]):
    im = ax.imshow(ssim_map[6, i, :, :], vmin=0, vmax=1, cmap='gray')
    ax.axis('off')
    ax.set_title(f"{band_31[i]}nm, SSIM: {ssim_map[6, i, :, :].mean():.3f}")
fig.colorbar(im, ax=axes.ravel().tolist(), pad = 0.01)
plt.show()

# %%
# visualize the sam map for 31 bands to understand which band has better ssim score
sam_map = np.array(results_m["sam_map"]).squeeze()
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 15))
for i, ax in enumerate(axes.flat[:-1]):
    im = ax.imshow(sam_map[i, :, :], vmin=0, vmax=1, cmap='gray')
    ax.axis('off')
    ax.set_title(f"SAM: {sam_map[i, :, :].mean():.3f}")
fig.colorbar(im, ax=axes.ravel().tolist(), pad = 0.01)
plt.show()
sam_map.shape
# Out:
# (30, 1024, 1024)

# %%
h, w, hwsize = 250, 500, 100
x, y = test_dataset[6]
y = y.numpy()
p = np.array(results_m["pred"]).squeeze()[6]

yy = y[:, h:h+hwsize, w:w+hwsize].reshape(-1, 10000)
yy_median = np.median(yy, axis=1)
yy_max = yy.max(1)
yy_min = yy.min(1)
pp = p[:, h:h+hwsize, w:w+hwsize].reshape(-1, 10000)
pp_median = np.median(pp, axis=1)
pp_max = pp.max(1)
pp_min = pp.min(1)

# %%
plt.imshow(x.permute(1, 2, 0).numpy())

# Add the patch to the Axes
plt.gca().add_patch(Rectangle((w,h),hwsize,hwsize,linewidth=1.2,edgecolor='r',facecolor='none'))

# %%
plt.plot(band_31, yy_median, label='Groud truth')
plt.fill_between(band_31, yy_min, yy_max, alpha=0.2)
plt.plot(band_31, pp_median, label='Prediction')
plt.fill_between(band_31, pp_min, pp_max, alpha=0.2)
plt.title('Spectral profile at (300, 500)')
plt.legend()
plt.ylabel('Reflectance')
plt.xlabel('Band')
plt.show()
